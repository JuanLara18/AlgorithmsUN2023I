# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanLara18/AlgorithmsUN2023I/blob/main/Lab3/jlaracognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Applied Data Science with Python in cognitiveclass.ai:

# %% [markdown]
# ## LinkedIn
#
# The link of my LinkdIn can be found [here](https://www.linkedin.com/in/juandavidlara/). In this you can see the certificates:

# %% [markdown]
# ![Captura de pantalla_20230226_113116.png](data:image/png;base64,...)

# %% [markdown]
# ## **Certificates**

# %% [markdown]
# ### Python 101 for Data Science

# %% [markdown]
# ![Captura de pantalla_20230226_113817.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Analysis with Python

# %% [markdown]
# ![Captura de pantalla_20230226_113824.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Analysis with Python

# %% [markdown]
# ![Captura de pantalla_20230226_113831.png](data:image/png;base64,...)
